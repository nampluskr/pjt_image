# %%
import pandas as pd
import pycaret.classification as caret

# %%
data = pd.read_csv("healthcare-dataset-stroke-data.csv")
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
from collections import Counter

counter = Counter(data['stroke'])
counter, counter[0]/counter[1], counter[0]/(counter[0] + counter[1]), counter[1]/(counter[0] + counter[1])
# Out:
# (Counter({1: 249, 0: 4861}),
#  19.522088353413654,
#  0.9512720156555773,
#  0.0487279843444227)

# %%
95/5
# Out:
# 19.0

# %%
from sklearn.model_selection import train_test_split

x = data.drop('stroke', axis=1)
y = data['stroke']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
train = pd.concat([x_train, y_train], axis=1)
test = pd.concat([x_test, y_test], axis=1)
train.shape, test.shape
# Out:
# ((3577, 12), (1533, 12))

# %%
from imblearn.under_sampling import RandomUnderSampler

sampler = RandomUnderSampler()
session = caret.setup(data=train, target='stroke', session_id=42, silent=True,
                      normalize=True, 
                    #   pca=True,)
                      remove_multicollinearity=True, )
                      # remove_perfect_collinearity=True,
                      # fix_imbalance=True, fix_imbalance_method=sampler)
# Out:
# <style type="text/css">
# #T_be1d1_row5_col1, #T_be1d1_row29_col1, #T_be1d1_row42_col1, #T_be1d1_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_be1d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be1d1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_be1d1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be1d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be1d1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_be1d1_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be1d1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_be1d1_row1_col1" class="data row1 col1" >stroke</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be1d1_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_be1d1_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be1d1_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_be1d1_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be1d1_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_be1d1_row4_col1" class="data row4 col1" >(3577, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be1d1_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_be1d1_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be1d1_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_be1d1_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be1d1_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_be1d1_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be1d1_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_be1d1_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be1d1_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_be1d1_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_be1d1_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_be1d1_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_be1d1_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_be1d1_row11_col1" class="data row11 col1" >(2503, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_be1d1_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_be1d1_row12_col1" class="data row12 col1" >(1074, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_be1d1_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_be1d1_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_be1d1_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_be1d1_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_be1d1_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_be1d1_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_be1d1_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_be1d1_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_be1d1_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_be1d1_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_be1d1_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_be1d1_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_be1d1_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_be1d1_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_be1d1_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_be1d1_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_be1d1_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_be1d1_row21_col1" class="data row21 col1" >da6a</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_be1d1_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_be1d1_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_be1d1_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_be1d1_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_be1d1_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_be1d1_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_be1d1_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_be1d1_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_be1d1_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_be1d1_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_be1d1_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_be1d1_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_be1d1_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_be1d1_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_be1d1_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_be1d1_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_be1d1_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_be1d1_row30_col0" class="data row30 col0" >Norm

# %%
# topk = caret.compare_models(n_select=3, sort='F1')

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

weights = compute_class_weight(class_weight='balanced',
                               classes=np.unique(y),
                               y=y)
weights, weights[1]/weights[0]
# Out:
# (array([ 0.52561201, 10.26104418]), 19.522088353413658)

# %%
lr = caret.create_model('lr', class_weight='balanced', cross_validation=False)
rf = caret.create_model('rf', class_weight='balanced', cross_validation=False)
et = caret.create_model('et', class_weight='balanced', cross_validation=False)
lightgbm = caret.create_model('lightgbm', class_weight='balanced', cross_validation=False)
xgboost = caret.create_model('xgboost', scale_pos_weight=0.95/0.05, cross_validation=False)
catboost = caret.create_model('catboost', class_weights=[0.05, 0.95], cross_validation=False)

models = [lr, rf, et, lightgbm, xgboost, catboost]
topk = caret.compare_models(n_select=5, sort='F1', include=models)
# Out:
# <style type="text/css">
# #T_9e7c7 th {
#   text-align: left;
# }
# #T_9e7c7_row0_col0, #T_9e7c7_row0_col1, #T_9e7c7_row0_col4, #T_9e7c7_row1_col0, #T_9e7c7_row1_col1, #T_9e7c7_row1_col2, #T_9e7c7_row1_col3, #T_9e7c7_row1_col4, #T_9e7c7_row1_col5, #T_9e7c7_row1_col6, #T_9e7c7_row1_col7, #T_9e7c7_row2_col0, #T_9e7c7_row2_col1, #T_9e7c7_row2_col2, #T_9e7c7_row2_col3, #T_9e7c7_row2_col4, #T_9e7c7_row2_col5, #T_9e7c7_row2_col6, #T_9e7c7_row2_col7, #T_9e7c7_row3_col0, #T_9e7c7_row3_col1, #T_9e7c7_row3_col2, #T_9e7c7_row3_col3, #T_9e7c7_row3_col5, #T_9e7c7_row3_col6, #T_9e7c7_row3_col7, #T_9e7c7_row4_col0, #T_9e7c7_row4_col1, #T_9e7c7_row4_col2, #T_9e7c7_row4_col3, #T_9e7c7_row4_col4, #T_9e7c7_row4_col5, #T_9e7c7_row4_col6, #T_9e7c7_row4_col7, #T_9e7c7_row5_col0, #T_9e7c7_row5_col2, #T_9e7c7_row5_col3, #T_9e7c7_row5_col4, #T_9e7c7_row5_col5, #T_9e7c7_row5_col6, #T_9e7c7_row5_col7 {
#   text-align: left;
# }
# #T_9e7c7_row0_col2, #T_9e7c7_row0_col3, #T_9e7c7_row0_col5, #T_9e7c7_row0_col6, #T_9e7c7_row0_col7, #T_9e7c7_row3_col4, #T_9e7c7_row5_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9e7c7_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_9e7c7_row1_col8, #T_9e7c7_row2_col8, #T_9e7c7_row3_col8, #T_9e7c7_row4_col8, #T_9e7c7_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9e7c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e7c7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9e7c7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9e7c7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9e7c7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9e7c7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9e7c7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9e7c7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9e7c7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_9e7c7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e7c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e7c7_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_9e7c7_row0_col1" class="data row0 col1" >0.7479</td>
#       <td id="T_9e7c7_row0_col2" class="data row0 col2" >0.8315</td>
#       <td id="T_9e7c7_row0_col3" class="data row0 col3" >0.7773</td>
#       <td id="T_9e7c7_row0_col4" class="data row0 col4" >0.1302</td>
#       <td id="T_9e7c7_row0_col5" class="data row0 col5" >0.2227</td>
#       <td id="T_9e7c7_row0_col6" class="data row0 col6" >0.1557</td>
#       <td id="T_9e7c7_row0_col7" class="data row0 col7" >0.2462</td>
#       <td id="T_9e7c7_row0_col8" class="data row0 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_9e7c7_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_9e7c7_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_9e7c7_row1_col1" class="data row1 col1" >0.9209</td>
#       <td id="T_9e7c7_row1_col2" class="data row1 col2" >0.8137</td>
#       <td id="T_9e7c7_row1_col3" class="data row1 col3" >0.1652</td>
#       <td id="T_9e7c7_row1_col4" class="data row1 col4" >0.1484</td>
#       <td id="T_9e7c7_row1_col5" class="data row1 col5" >0.1527</td>
#       <td id="T_9e7c7_row1_col6" class="data row1 col6" >0.1126</td>
#       <td id="T_9e7c7_row1_col7" class="data row1 col7" >0.1141</td>
#       <td id="T_9e7c7_row1_col8" class="data row1 col8" >2.6200</td>
#     </tr>
#     <tr>
#       <th id="T_9e7c7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9e7c7_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9e7c7_row2_col1" class="data row2 col1" >0.9277</td>
#       <td id="T_9e7c7_row2_col2" class="data row2 col2" >0.8170</td>
#       <td id="T_9e7c7_row2_col3" class="data row2 col3" >0.1053</td>
#       <td id="T_9e7c7_row2_col4" class="data row2 col4" >0.1314</td>
#       <td id="T_9e7c7_row2_col5" class="data row2 col5" >0.1130</td>
#       <td id="T_9e7c7_row2_col6" class="data row2 col6" >0.0772</td>
#       <td id="T_9e7c7_row2_col7" class="data row2 col7" >0.0789</td>
#       <td id="T_9e7c7_row2_col8" class="data row2 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_9e7c7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9e7c7_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_9e7c7_row3_col1" class="data row3 col1" >0.9365</td>
#       <td id="T_9e7c7_row3_col2" class="data row3 col2" >0.7974</td>
#       <td id="T_9e7c7_row3_col3" class="data row3 col3" >0.0773</td>
#       <td id="T_9e7c7_row3_col4" class="data row3 col4" >0.1732</td>
#       <td id="T_9e7c7_row3_col5" class="data row3 col5" >0.1020</td>
#       <td id="T_9e7c7_row3_col6" class="data row3 col6" >0.0731</td>
#       <td id="T_9e7c7_row3_col7" class="data row3 col7" >0.0820</td>
#       <td id="T_9e7c7_row3_col8" class="data row3 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_9e7c7_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_9e7c7_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_9e7c7_row4_col1" class="data row4 col1" >0.9513</td>
#       <td id="T_9e7c7_row4_col2" class="data row4 col2" >0.7489</td>
#       <td id="T_9e7c7_row4_col3" class="data row4 col3" >0.0356</td>
#       <td id="T_9e7c7_row4_col4" class="data row4 col4" >0.1233</td>
#       <td id="T_9e7c7_row4_col5" class="data row4 col5" >0.0536</td>
#       <td id="T_9e7c7_row4_col6" class="data row4 col6" >0.0458</td>
#       <td id="T_9e7c7_row4_col7" class="data row4 col7" >0.0546</td>
#       <td id="T_9e7c7_row4_col8" class="data row4 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_9e7c7_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_9e7c7_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_9e7c7_row5_col1" class="data row5 col1" >0.9533</td>
#       <td id="T_9e7c7_row5_col2" class="data row5 col2" >0.7940</td>
#       <td id="T_9e7c7_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_9e7c7_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_9e7c7_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_9e7c7_row5_col6" class="data row5 col6" >-0.0007</td>
#       <td id="T_9e7c7_row5_col7" class="data row5 col7" >-0.0014</td>
#       <td id="T_9e7c7_row5_col8" class="data row5 col8" >0.0790</td>
#     </tr>
#   </tbody>
# </table>

# %%
topk_tuned = [caret.tune_model(model, optimize='F1', 
                               choose_better=True) for model in topk]
# Out:
# <style type="text/css">
# #T_5e012_row10_col0, #T_5e012_row10_col1, #T_5e012_row10_col2, #T_5e012_row10_col3, #T_5e012_row10_col4, #T_5e012_row10_col5, #T_5e012_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_5e012_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e012_row6_col0" class="data row6 col0" >0.7080</td>
#       <td id="T_5e012_row6_col1" class="data row6 col1" >0.8667</td>
#       <td id="T_5e012_row6_col2" class="data row6 col2" >0.8182</td>
#       <td id="T_5e012_row6_col3" class="data row6 col3" >0.1125</td>
#       <td id="T_5e012_row6_col4" class="data row6 col4" >0.1978</td>
#       <td id="T_5e012_row6_col5" class="data row6 col5" >0.1305</td>
#       <td id="T_5e012_row6_col6" class="data row6 col6" >0.2291</td>
#     </tr>
#     <tr>
#       <th id="T_5e012_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e012_row7_col0" class="data row7 col0" >0.7200</td>
#       <td id="T_5e012_row7_col1" class="data row7 col1" >0.8759</td>
#       <td id="T_5e012_row7_col2" class="data row7 col2" >0.9167</td>
#       <td id="T_5e012_row7_col3" class="data row7 col3" >0.1375</td>
#       <td id="T_5e012_row7_col4" class="data row7 col4" >0.2391</td>
#       <td id="T_5e012_row7_col5" class="data row7 col5" >0.1698</td>
#       <td id="T_5e012_row7_col6" class="data row7 col6" >0.2872</td>
#     </tr>
#     <tr>
#       <th id="T_5e012_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e012_row8_col0" class="data row8 col0" >0.7120</td>
#       <td id="T_5e012_row8_col1" class="data row8 col1" >0.8906</td>
#       <td id="T_5e012_row8_col2" class="data row8 col2" >0.8333</td>
#       <td id="T_5e012_row8_col3" class="data row8 col3" >0.1250</td>
#       <td id="T_5e012_row8_col4" class="data row8 col4" >0.2174</td>
#       <td id="T_5e012_row8_col5" class="data row8 col5" >0.1461</td>
#       <td id="T_5e012_row8_col6" class="data row8 col6" >0.2471</td>
#     </tr>
#     <tr>
#       <th id="T_5e012_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e012_row9_col0" class="data row9 col0" >0.7720</td>
#       <td id="T_5e012_row9_col1" class="data row9 col1" >0.7570</td>
#       <td id="T_5e012_row9_col2" class="data row9 col2" >0.5833</td>
#       <td id="T_5e012_row9_col3" class="data row9 col3" >0.1186</td>
#       <td id="T_5e012_row9_col4" class="data row9 col4" >0.1972</td>
#       <td id="T_5e012_row9_col5" class="data row9 col5" >0.1276</td>
#       <td id="T_5e012_row9_col6" class="data row9 col6" >0.1837</td>
#     </tr>
#     <tr>
#       <th id="T_5e012_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5e012_row10_col0" class="data row10 col0" >0.7247</td>
#       <td id="T_5e012_row10_col1" class="data row10 col1" >0.8374</td>
#       <td id="T_5e012_row10_col2" class="data row10 col2" >0.8038</td>
#       <td id="T_5e012_row10_col3" class="data row10 col3" >0.1224</td>
#       <td id="T_5e012_row10_col4" class="data row10 col4" >0.2121</td>
#       <td id="T_5e012_row10_col5" class="data row10 col5" >0.1434</td>
#       <td id="T_5e012_row10_col6" class="data row10 col6" >0.2395</td>
#     </tr>
#     <tr>
#       <th id="T_5e012_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5e012_row11_col0" class="data row11 col0" >0.0186</td>
#       <td id="T_5e012_row11_col1" class="data row11 col1" >0.0389</td>
#       <td id="T_5e012_row11_col2" class="data row11 col2" >0.1036</td>
#       <td id="T_5e012_row11_col3" class="data row11 col3" >0.0085</td>
#       <td id="T_5e012_row11_col4

# %%
blender = caret.blend_models(topk_tuned, optimize='F1', choose_better=True)
# Out:
# <style type="text/css">
# #T_50c73_row10_col0, #T_50c73_row10_col1, #T_50c73_row10_col2, #T_50c73_row10_col3, #T_50c73_row10_col4, #T_50c73_row10_col5, #T_50c73_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T
td>
#     </tr>
#     <tr>
#       <th id="T_50c73_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50c73_row6_col0" class="data row6 col0" >0.8760</td>
#       <td id="T_50c73_row6_col1" class="data row6 col1" >0.8631</td>
#       <td id="T_50c73_row6_col2" class="data row6 col2" >0.5455</td>
#       <td id="T_50c73_row6_col3" class="data row6 col3" >0.1875</td>
#       <td id="T_50c73_row6_col4" class="data row6 col4" >0.2791</td>
#       <td id="T_50c73_row6_col5" class="data row6 col5" >0.2285</td>
#       <td id="T_50c73_row6_col6" class="data row6 col6" >0.2681</td>
#     </tr>
#     <tr>
#       <th id="T_50c73_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_50c73_row7_col0" class="data row7 col0" >0.8120</td>
#       <td id="T_50c73_row7_col1" class="data row7 col1" >0.8627</td>
#       <td id="T_50c73_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_50c73_row7_col3" class="data row7 col3" >0.1818</td>
#       <td id="T_50c73_row7_col4" class="data row7 col4" >0.2985</td>
#       <td id="T_50c73_row7_col5" class="data row7 col5" >0.2385</td>
#       <td id="T_50c73_row7_col6" class="data row7 col6" >0.3325</td>
#     </tr>
#     <tr>
#       <th id="T_50c73_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_50c73_row8_col0" class="data row8 col0" >0.8480</td>
#       <td id="T_50c73_row8_col1" class="data row8 col1" >0.9090</td>
#       <td id="T_50c73_row8_col2" class="data row8 col2" >0.8333</td>
#       <td id="T_50c73_row8_col3" class="data row8 col3" >0.2174</td>
#       <td id="T_50c73_row8_col4" class="data row8 col4" >0.3448</td>
#       <td id="T_50c73_row8_col5" class="data row8 col5" >0.2908</td>
#       <td id="T_50c73_row8_col6" class="data row8 col6" >0.3763</td>
#     </tr>
#     <tr>
#       <th id="T_50c73_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_50c73_row9_col0" class="data row9 col0" >0.8280</td>
#       <td id="T_50c73_row9_col1" class="data row9 col1" >0.7374</td>
#       <td id="T_50c73_row9_col2" class="data row9 col2" >0.5000</td>
#       <td id="T_50c73_row9_col3" class="data row9 col3" >0.1395</td>
#       <td id="T_50c73_row9_col4" class="data row9 col4" >0.2182</td>
#       <td id="T_50c73_row9_col5" class="data row9 col5" >0.1547</td>
#       <td id="T_50c73_row9_col6" class="data row9 col6" >0.1952</td>
#     </tr>
#     <tr>
#       <th id="T_50c73_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_50c73_row10_col0" class="data row10 col0" >0.8274</td>
#       <td id="T_50c73_row10_col1" class="data row10 col1" >0.8496</td>
#       <td id="T_50c73_row10_col2" class="data row10 col2" >0.6902</td>
#       <td id="T_50c73_row10_col3" class="data row10 col3" >0.1693</td>
#       <td id="T_50c73_row10_col4" class="data row10 col4" >0.2707</td>
#       <td id="T_50c73_row10_col5" class="data row10 col5" >0.2122</td>
#       <td id="T_50c73_row10_col6" class="data row10 col6" >0.2814</td>
#     </tr>
#     <tr>
#       <th id="T_50c73_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_50c73_row11_col0" class="data row11 col0" >0.0239</td>
#       <td id="T_50c73_row11_col1" class="data row11 col1" >0.0432</td>
#       <td id="T_50c73_row11_col2" class="data row11 col2" >0.1139</td>
#       <td id="T_50c73_row11_col3" class="data row11 col3" >0.0224</td>
#       <td id="T_50c73_row11_col4

# %%
caret.predict_model(blender, data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e21e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e21e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1e21e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1e21e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1e21e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1e21e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1e21e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1e21e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1e21e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e21e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e21e_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_1e21e_row0_col1" class="data row0 col1" >0.8382</td>
#       <td id="T_1e21e_row0_col2" class="data row0 col2" >0.8387</td>
#       <td id="T_1e21e_row0_col3" class="data row0 col3" >0.6517</td>
#       <td id="T_1e21e_row0_col4" class="data row0 col4" >0.2109</td>
#       <td id="T_1e21e_row0_col5" class="data row0 col5" >0.3187</td>
#       <td id="T_1e21e_row0_col6" class="data row0 col6" >0.2532</td>
#       <td id="T_1e21e_row0_col7" class="data row0 col7" >0.3056</td>
#     </tr>
#   </tbody>
# </table>
#          id  gender   age  hypertension  heart_disease ever_married  \
# 4688  40041    Male  31.0             0              0           No
# 4478  55244    Male  40.0             0              0          Yes
# 3849  70992  Female   8.0             0              0           No
# 4355  38207  Female  79.0             1              0          Yes
# 3826   8541  Female  75.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 818    7663    Male  20.0             0              0           No
# 4829  66067    Male  66.0             0              0          Yes
# 611   30753    Male  42.0             0              0          Yes
# 3082  66270  Female  57.0             0              0          Yes
# 3407  10243  Female  60.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 4688  Self-employed          Rural              64.85  23.0          Unknown
# 4478  Self-employed          Rural              65.29  28.3     never smoked
# 3849       children          Urban              74.42  22.5          Unknown
# 4355  Self-employed          Rural              76.64  19.5     never smoked
# 3826       Govt_job          Rural              94.77  27.2     never smoked
# ...             ...            ...                ...   ...              ...
# 818        Govt_job          Rural             106.97  27.9  formerly smoked
# 4829        Private          Rural              67.92  31.1  formerly smoked
# 611        Govt_job          Urban              93.79  27.2     never smoked
# 3082        Private          Rural              69.40  24.0          Unknown
# 3407       Govt_job          Urban              73.04  25.3     never smoked
#
#       stroke  Label   Score
# 4688       0      0  0.8108
# 4478       0      0  0.7856
# 3849       0      0  0.8212
# 4355       0      1  0.6160
# 3826       0      1  0.5556
# ...      ...    ...     ...
# 818        0      0  0.8252
# 4829       0      0  0.5909
# 611        0      0  0.7844
# 3082       0      0  0.6068
# 3407       0      0  0.6723
#
# [1533 rows x 14 columns]

# %%
best_model = caret.finalize_model(blender)
caret.predict_model(best_model, data=test)
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# <style type="text/css">
# </style>
# <table id="T_3377f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3377f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3377f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3377f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3377f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3377f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3377f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3377f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3377f_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3377f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3377f_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_3377f_row0_col1" class="data row0 col1" >0.8311</td>
#       <td id="T_3377f_row0_col2" class="data row0 col2" >0.8482</td>
#       <td id="T_3377f_row0_col3" class="data row0 col3" >0.6404</td>
#       <td id="T_3377f_row0_col4" class="data row0 col4" >0.2007</td>
#       <td id="T_3377f_row0_col5" class="data row0 col5" >0.3056</td>
#       <td id="T_3377f_row0_col6" class="data row0 col6" >0.2383</td>
#       <td id="T_3377f_row0_col7" class="data row0 col7" >0.2909</td>
#     </tr>
#   </tbody>
# </table>
#          id  gender   age  hypertension  heart_disease ever_married  \
# 4688  40041    Male  31.0             0              0           No
# 4478  55244    Male  40.0             0              0          Yes
# 3849  70992  Female   8.0             0              0           No
# 4355  38207  Female  79.0             1              0          Yes
# 3826   8541  Female  75.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 818    7663    Male  20.0             0              0           No
# 4829  66067    Male  66.0             0              0          Yes
# 611   30753    Male  42.0             0              0          Yes
# 3082  66270  Female  57.0             0              0          Yes
# 3407  10243  Female  60.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 4688  Self-employed          Rural              64.85  23.0          Unknown
# 4478  Self-employed          Rural              65.29  28.3     never smoked
# 3849       children          Urban              74.42  22.5          Unknown
# 4355  Self-employed          Rural              76.64  19.5     never smoked
# 3826       Govt_job          Rural              94.77  27.2     never smoked
# ...             ...            ...                ...   ...              ...
# 818        Govt_job          Rural             106.97  27.9  formerly smoked
# 4829        Private          Rural              67.92  31.1  formerly smoked
# 611        Govt_job          Urban              93.79  27.2     never smoked
# 3082        Private          Rural              69.40  24.0          Unknown
# 3407       Govt_job          Urban              73.04  25.3     never smoked
#
#       stroke  Label   Score
# 4688       0      0  0.8079
# 4478       0      0  0.7833
# 3849       0      0  0.8202
# 4355       0      1  0.6826
# 3826       0      1  0.5444
# ...      ...    ...     ...
# 818        0      0  0.8230
# 4829       0      0  0.5773
# 611        0      0  0.7849
# 3082       0      0  0.6257
# 3407       0      0  0.6517
#
# [1533 rows x 14 columns]

# %%
xgboost.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.300000012,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 6,
#  'max_leaves': 0,
#  'min_child_weight': 1,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 42,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': 'uniform',
#  'scale_pos_weight': 18.999999999999996,
#  'subsample': 1,
#  'tree_method': 'auto',
#  'validate_parameters': 1,
#  'verbosity': 0}

# %%
best_model.estimators
# Out:
# [('lr',
#   LogisticRegression(C=2.214, class_weight='balanced', dual=False,
#                      fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                      max_iter=1000, multi_class='auto', n_jobs=None, penalty='l2',
#                      random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                      warm_start=False)),
#  ('catboost', <catboost.core.CatBoostClassifier at 0x7f76c8bbb3d0>),
#  ('lightgbm',
#   LGBMClassifier(bagging_fraction=0.8, bagging_freq=7, boosting_type='gbdt',
#                  class_weight='balanced', colsample_bytree=1.0,
#                  feature_fraction=0.8, importance_type='split', learning_rate=0.4,
#                  max_depth=-1, min_child_samples=16, min_child_weight=0.001,
#                  min_split_gain=0.7, n_estimators=100, n_jobs=-1, num_leaves=90,
#                  objective=None, random_state=42, reg_alpha=1, reg_lambda=3,
#                  silent='warn', subsample=1.0, subsample_for_bin=200000,
#                  subsample_freq=0)),
#  ('xgboost',
#   XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#                 colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.9,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#                 importance_type=None, interaction_constraints='',
#                 learning_rate=1e-06, max_bin=256, max_cat_to_onehot=4,
#                 max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=2,
#                 missing=nan, monotone_constraints='()', n_estimators=100,
#                 n_jobs=-1, num_parallel_tree=1, objective='binary:logistic',
#                 predictor='auto', random_state=42, reg_alpha=2, ...)),
#  ('et',
#   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=1, max_features=1.0, max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0002,
#                        min_impurity_split=None, min_samples_leaf=5,
#                        min_samples_split=7, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=42, verbose=0, warm_start=False))]
